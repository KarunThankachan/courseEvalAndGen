# %%
# !git clone https://github.com/salesforce/cove.git # use ssh: git@github.com:salesforce/cove.git
# !cd cove
# !pip install -r cove/requirements.txt
# !python cove/setup.py develop
# Out:
# Cloning into 'cove'...
# remote: Enumerating objects: 130, done.
# remote: Total 130 (delta 0), reused 0 (delta 0), pack-reused 130
# Receiving objects: 100% (130/130), 47.54 KiB | 132.00 KiB/s, done.
# Resolving deltas: 100% (48/48), done.
# ...
#   Cloning git://github.com/jekbradbury/revtok.git to /tmp/pip-req-build-1xlvez6f
#   Running command git clone -q git://github.com/jekbradbury/revtok.git /tmp/pip-req-build-1xlvez6f
# ...
#   Cloning https://github.com/pytorch/text.git to /tmp/pip-req-build-y7wq1520
#   Running command git clone -q https://github.com/pytorch/text.git /tmp/pip-req-build-y7wq1520
# ...
#      |████████████████████████████████| 890kB 2.7MB/s
# ...
#      |████████████████████████████████| 6.4MB 12.0MB/s
# ...
#      |████████████████████████████████| 71kB 8.8MB/s
# ...
#      |████████████████████████████████| 1.0MB 46.9MB/s
# ...
#      |████████████████████████████████| 61kB 9.3MB/s
# ...
#      |████████████████████████████████| 51kB 7.5MB/s
# ...
#      |████████████████████████████████| 235kB 50.9MB/s
# ...

# %%
concepts = {"Amazon Cloudfront": ["183"], "Amazon CloudWatch": ["182"], "Amazon DevPay": ["183"], "Amazon Elastic Block Store (EBS)": ["198"], "account creation": ["190-196"], "Amazon Machine Images (AMIs)": ["186-187"], "IaaS model": ["11"], "instances": ["190-196"], "WaveMaker 4GL version support": ["147"], "Amazon Elastic MapReduce": ["183"], "Amazon Flexible Payments Service": ["184"], "Quick Starts": ["184"], "Amazon Fulfillment Web Services": ["184"], "order fillers": ["184"], "EC2 account creation": ["190-196"], "EC2 instance creation": ["190-196"], "EC2 service zones": ["189"], "Elastic IP Address": ["189"], "Elastic Load Balancing": ["182"], "hardware platform emulation": ["185"], "high CPU instances": ["186-187"], "high memory instances": ["186-187"], "On-Demand Instance": ["187-188"], "Reserved Instances": ["187-188"], "standard instances": ["186-187"], "supported operating systems": ["188-189"], "system images": ["107"], "virtual appliances": ["52", "53"], "Amazon Mechanical Turk": ["183"], "Amazon Relational Database Service (RDS)": ["182", "201-202"], "Amazon S3 Web services": ["143"], "Amazon Simple Monthly Calculator": ["34"], "Amazon Simple Notification Service": ["181"], "Amazon Simple Queue Service": ["181"], "Amazon Simple Storage System (S3)": ["196-197"], "Amazon SimpleDB": ["182"], "Amazon Virtual Private Cloud": ["184"], "10 Laws of Behavioral Cloudonomics": ["31-33"], "10 Laws of Cloudonomics": ["27-28"], "Joe Wienman": ["27-28"], "30 Boxes": ["351"], "online calendar program": ["351"], "3-2-1 Rule": ["327"], "data backups": ["327"], "3Tera": ["244"], "cloud management": ["244"], "abstraction": ["4"], "cloud computing concepts": ["4"], "access control": ["214-216", "256"], "access": ["17"], "virtualization characteristic": ["94"], "account management": ["183"], "accounting packages": ["340"], "accounts": ["190-196", "409"], "ACID principle": ["298-299"], "Acrobat.com": ["343"], "Actional 8.0": ["294"], "SOA security": ["294"], "Azure": ["266"], "address books": ["344"], "Contact": ["344"], "Adium": ["387"], "instant messaging": ["221"], "administration of resources": ["232"], "AdMob": ["430"], "smartphone study": ["430"], "ADO.NET Data Services Framework": ["57"], "Adobe Flash": ["416", "418-419"], "Advanced Encryption Standard (AES)": ["409"], "Skype": ["409-411"], "AdWords": ["161"], "Google Web service": ["162-163"], "Afilias": ["448"], "dotMOBI registry": ["448-449"], "aggregation pages": ["156"], "Google": ["81"], "aggregation": ["69-70"], "IaaS": ["69-70"], "aggregators": ["399-400"], "social networking": ["221"], "AJAX APIs": ["165"], "Google development service": ["165"], "Akamai Technologies": ["97", "199"], "Alerta": ["116"], "Web site performance monitor": ["116"], "Alexa Top Sites": ["183"], "Alexa Web Information Service": ["183"], "Amazon Associates Web Services": ["183"], "application servers": ["68"], "application services": ["103"], "VMware service": ["103"], "Application Tracking System": ["359"], "People": ["359"], "architectural layers": ["51-55"], "attribute map": ["300"], "attributes": ["95"], "BlackBerry App World": ["440"], "cloud APIs": ["308"], "cloud bursting": ["304-307"], "cloud service attributes": ["302-303"], "cloud transactions": ["298-307"], "functionality mapping": ["299-300"], "Google Web services": ["151-152"], "mobile devices": ["419"], "office suites": ["340-341"], "porting": ["108-110"], "system abstraction": ["303-304"], "Voice over IP (VoIP)": ["409-411"], "Windows Azure Platform element": ["211", "213"], "Windows Live Essentials": ["224"], "Apps.gov": ["8-9"], "cloud computing portal": ["8-9"], "AppScale": ["175"], "Google App Engine (GAE)": ["165", "173"], "AppSight": ["293"], "AppZero": ["109"], "applications": ["224-226"], "communication protocols": ["55-56"], "composability": ["46-48"], "infrastructure": ["48-49"], "platforms": ["49-51"], "architectural standards": ["19"], "architecture design": ["289"], "archival storage": ["26"], "Aristotle": ["81"], "API for identity interchange": ["81"], "AroundMe iPhone app": ["267"], "ArtsandLettersDaily.com": ["380"], "Asynchronous JavaScript and XML (Ajax)": ["27", "74"], "athenahealth": ["88"], "CaaS capabilities": ["88"], "Atom Publishing Protocol (APP)": ["57"], "attached backups": ["331-332"], "Amazon Machine Image (AMI)": ["108"], "Auto Scaling": ["182"], "availability zones": ["69-70"], "AWS Management Console": ["69", "190-196"], "components and services": ["181-184"], "Elastic Compute Cloud (EC2)": ["42", "181-182", "185-196"], "Infrastructure as a Service (IaaS)": ["209"], "iPhone application hosting service": ["436"], "private virtual servers": ["179"], "revenue statistics": ["180-181"], "SAS70 Type II Audits": ["262"], "Service Oriented Architecture (SOA)": ["69"], "SOA standards": ["179-180"], "software types": ["189"], "usage-based developer platform": ["179"], "Amazon.com Simple Storage Service": ["320"], "analysis": ["289"], "SOMF element": ["289"], "anchored lifecycle applications": ["133"], "PaaS": ["138"], "AnchorFree Hotspot Shield": ["59"], "VPN software": ["59"], "Android Market applications": ["433"], "Android": ["165"], "mobile device operating system": ["441-442"], "AOL Instant Messenger": ["384-385"], "Apache": ["115"], "Drupal applications": ["140"], "Apache HTTP Server": ["115"], "App Engine": ["70-71"], "Platform as a Service (PaaS)": ["12", "13", "49", "205", "209"], "App Store": ["434-435"], "Apple iPhone": ["433-438"], "Apparent Networks": ["129"], "AppFabric": ["40"], "Service Level Agreements (SLAs)": ["40"], "Apple MobileMe": ["457"], "Apple Safari": ["416"], "YouTube support": ["419"], "Apple\u2019s Time Machine": ["326"], "AppleTV": ["415"], "digital media receiver": ["415"], "Application Deliver Controller (ADC)": ["96-97"], "Application Delivery Network (ADN)": ["97"], "application development": ["134", "137-138"], "PaaS service": ["134"], "application instances": ["95"], "application launcher": ["62-63"], "Chrome OS": ["61-64"], "Application Oriented Networking": ["293"], "Application Programming Interface (API)": ["46"], "Amazon Simple Storage System": ["182"], "cloud storage characteristics": ["327-328"], "cloud storage types": ["325-327"], "continuous data protection (CDP)": ["326"], "data archival": ["327"], "differential": ["326"], "full system": ["325"], "image": ["325"], "incremental": ["326"], "mirroring": ["327"], "open file": ["326"], "point-in-time (PIT)": ["326"], "Reverse Delta": ["326"], "Bagvapp": ["53"], "bandwidth": ["404-405"], "bankserv": ["88"], "Barksdale": ["156"], "Karl (Google Apps For Dummies)": ["156"], "Barracuda Networks": ["96"], "ADC systems": ["97"], "baseline measurements": ["115-118"], "capacity planning": ["116-117"], "Architecture": ["275"], "Discovery and Anlysis": ["275"], "(MDS-CS)": ["439"], "Bias": ["181"], "Randy": ["181"], "Cloudscaling.com blogger": ["181"], "BigBlueBall.com": ["387"], "instant messaging interoperability": ["387-388"], "billing management": ["183"], "Calculator": ["34-35"], "billing": ["234"], "network management characteristic": ["234"], "(CHAP)": ["264"], "BlackBerry Enterprise Server (BES)": ["439"], "BlackBerry Internet Service (BIS)": ["439"], "BlackBerry Push Service": ["458"], "BlackBerry": ["438-440"], "blip TV": ["412"], "video streaming": ["413"], "Blogger": ["81"], "OpenID trusted provider": ["81"], "virtualization": ["94-95"], "audio files": ["344", "406-408"], "data security mechanism": ["256"], "security concerns": ["398"], "security element": ["261-263"], "AWS Multi-Factor Authentication": ["184"], "Challenge and Response Protocol (CHAP)": ["264"], "Enterprise Service Bus (ESB)": ["278-281"], "authentication services": ["78"], "IDaaS": ["80"], "authorization": ["264-265"], "authorization markup languages": ["84-87"], "Autobench": ["121"], "Web server request replay": ["121"], "automated software updates": ["456"], "autonomic systems": ["19"], "IaaS pods": ["69-70"], "AWS Import/Export": ["182"], "AWS Premium Support": ["184"], "AWS Security Center": ["251"], "AWS Simple Monthly Calculator": ["188"], "Azure AppFabric": ["214-216"], "Azure Content Delivery Network (CDN)": ["216-217"], "Azure Dynamic CRM": ["205"], "AppBase integration": ["143"], "Azure TCO Calculator": ["38-39"], ".NET Framework platform": ["5", "13"], "PaaS model": ["24"], "Software as a Service (SaaS) model": ["24"], "Azure Storage Service": ["211", "213"], "Windows Azure Platform": ["209", "308"], "backbones": ["28-29"], "network": ["28-29"], "BackEndBattles.com": ["162"], "time management": ["351"], "Planner": ["357"], "call center services": ["15-16"], "Capability Maturity Model Integration (CMMI)": ["245"], "instance types": ["126-128"], "LAMP performance monitoring tools": ["120"], "LAMP solution stack": ["115"], "load testing": ["121-122"], "machine instance resources": ["118"], "matching demand to available resources": ["113-114"], "resource ceilings": ["122-125"], "server types": ["126-128"], "system metrics": ["118-120"], "time scales": ["116-117"], "workflow process": ["404-405"], "capital expenditures": ["35-37"], "Carbonite": ["326"], "point-in-time (PIT) backups": ["326"], "CardSpace": ["82"], "Cassatt": ["245"], "Casual Vector Engine (CVE)": ["277-278"], "SOA 2.0": ["277-278"], "catalog service": ["281-282"], "SOA": ["288"], "(ADN)": ["97"], "feature phones": ["430"], "Internet Messaging and Presence Service (IMPS)": ["387"], "Short Message Service (SMS)": ["389-391"], "Windows Live for Mobile": ["227-228"], "central processing units (CPUs)": ["94", "118"], "Certeon": ["108"], "optimization appliances": ["108"], "CETRA": ["331"], "Cloud Attached Storage server": ["331-332"], "authentication": ["81"], "challenges": ["29-31"], "cloud computing obstacles": ["29-31"], "Chat": ["358"], "ZoHo Office Suite": ["356"], "chats": ["410"], "Skype support": ["410"], "Chromium OS": ["62"], "open source cloud client": ["62"], "circular topology": ["289-291"], "SOMF message passing": ["289-291"], "Cisco Jabber XCP": ["386"], "Cisco Systems": ["96"], "Cisco": ["293"], "Citrix GoToMeeting": ["391"], "Bloglines": ["377"], "newsreader": ["377", "379"], "blogs": ["394"], "Bloomberg Messaging": ["388"], "Blue Coat Systems": ["97"], "BMC Cloud Computing": ["233"], "BMC ProactiveNet Performance Management": ["232"], "BMC Software": ["293"], "BONDI API": ["449"], "Break.com": ["413"], "broad network": ["17"], "broadband": ["427"], "mobile device subscriptions": ["427"], "Brocade Communication Systems": ["96"], "brokered data access": ["256-259"], "proxy/broker service": ["256-259"], "Portal": ["345"], "YouTube compatible": ["416"], "buddies": ["393"], "social networking element": ["394"], "Builtwith.com": ["162"], "Burton Group": ["79"], "IaaS trademark": ["79"], "Business Explorer for Web Services": ["451"], "Business Objects Build": ["142"], "Business Process Designer": ["142"], "(WS-BPEL)": ["286-287"], "Buzzword": ["343", "345"], "Acrobat.com tools": ["344"], "Bycast": ["321-322"], "StorageGRID": ["321"], "CA Cloud Compose": ["244"], "cloud metrics measurement service": ["244"], "Service Measurement Index (SMI)": ["245", "246-248"], "CA Cloud Optimize": ["244"], "CA Cloud Orchestrate": ["244"], "CloudSensor": ["247"], "distributed network performance metrics": ["244-248"], "CA Wily SOA Solution": ["293"], "Calc": ["354"], "ThinkFree Office": ["354"], "Calendar application": ["344"], "Glide Digital application": ["344"], "backup characteristics": ["327-328"], "backup solutions listing": ["328-331"], "backup types": ["325-327"], "characteristics": ["94"], "Cloud Data Management Interface (CDMI)": ["311-312", "333-335"], "data storage statistics": ["312-314"], "future trends": ["314-315"], "interoperability": ["446"], "managed storage": ["311"], "Open Cloud Computing Interface (OCCI)": ["312", "335-336"], "out-of-band management systems": ["335"], "system creation": ["321-322"], "unmanaged storage": ["311", "316-319"], "virtual containers": ["322-325"], "Cloud to Cloud (C2C)": ["95"], "Cloud to Datacenter (C2D)": ["95"], "CloudFront": ["199"], "edge computing": ["199"], "Cloudkick": ["240"], "infrastructure monitoring": ["240-242"], "Cloudscaling.com": ["67", "181"], "codes of conduct": ["79"], "Collaboration": ["345"], "Dimdim": ["392"], "Zimbra Collaboration Suite": ["392"], "collaboration applications": ["26"], "Comet": ["456"], "push service": ["456"], "Common Information Model (CIM)": ["243"], "(CORBA)": ["57"], "(CALEA)": ["409"], "communications": ["282-292"], "community cloud": ["8-9"], "deployment model": ["7-9"], "Compliance as a Service (CaaS)": ["87-88"], "compliance": ["261-263"], "Citrix Systems": ["96"], "Clark": ["155"], "Ian": ["155"], "Freenet": ["155"], "ClearPoint PCI": ["88"], "click-through rate (CTR)": ["161"], "(CARML)": ["81"], "client/server protocols": ["55"], "cloud connection methods": ["58-64"], "Jolicloud netbook OS": ["60-61"], "Cloud API": ["308"], "Cloud Commons": ["245"], "Cloud Reference Model": ["253-255"], "defined": ["431"], "deployment models": ["5-6", "7-9"], "Internet characteristics": ["4"], "service models": ["10", "13"], "streaming media advantages": ["405-406"], "Cloud Computing Interoperability Forum": ["308"], "CLOUD conference": ["21"], "Cloud Connected Management Suite": ["244"], "Cloud Control System (CCS)": ["69"], "Cloud Cube Model": ["6-7"], "automated deployment": ["240"], "CA Technologies": ["244"], "DMTF standards": ["243-244"], "Open Virtualization Format (OVF)": ["107"], "product listing": ["156-159"], "service characteristics": ["240"], "Virtual Management Initiative (VMAN)": ["243"], "Cloud Performance Scorecard": ["129"], "Cloud Security Alliance (CSA)": ["252"], "data analytics": ["362-363"], "data archival backups": ["327"], "data computation": ["26"], "data encryption": ["59"], "data exchanges": ["57"], "data integrity": ["250"], "data interchange formats": ["282-283"], "data interchange standards": ["341"], "data locations": ["6-7"], "data management": ["134"], "data portals": ["137"], "PaaS type": ["137"], "data registries": ["280-281"], "data repositories": ["280-281"], "data services": ["280-281"], "data storage": ["259-260"], "data transfers": ["18", "57", "74"], "database management systems": ["340"], "database servers": ["125"], "AWS selection criteria": ["202"], "Creator": ["357"], "eCommerce system component": ["68"], "SQL Azure": ["217"], "Datacenter to Cloud (D2C)": ["94"], "Datacenter to Datacenter (D2D)": ["95"], "DataCenterKnowledge.com": ["98"], "cloud computing characteristics": ["4"], "deployment cost formulas": ["33-34"], "Google site factors": ["98"], "greenfield sites": ["28"], "DataPortability Project": ["265"], "DataViz Roadsync": ["457"], "push e-mail": ["457"], "Deep Web": ["155"], "search engine suppression": ["155"], "Defense Information Systems Agency (DISA)": ["268"], "deployment costs": ["33-34"], "formula": ["33-34"], "desktop publishing": ["340"], "desktop visualization": ["26"], "development servers": ["147"], "Device Description Repository": ["446"], "Device Description Working Group": ["446"], "differential backups": ["326"], "composite business applications": ["137"], "virtual machine instances": ["207"], "modeling tools": ["272"], "Computer Associates Cloud Solutions": ["233"], "Computer Industry Almanac": ["426"], "computer system assignment processing": ["95"], "conceptualization": ["289"], "conferencing": ["358"], "Meeting": ["358"], "Config": ["211", "213"], "connections": ["28-29"], "connectivity": ["118"], "machine instance resource": ["118"], "ConnectNow": ["343"], "consultation services": ["184"], "containers": ["101", "322-325"], "content delivery network (CDN)": ["199", "216-217"], "content delivery services": ["26"], "content management": ["357"], "Notebook": ["357"], "content management system (CMS)": ["138-139"], "content-delivery systems": ["183"], "ContextMine": ["399"], "social networking aggregator": ["399"], "continuous data protection (CDP) backups": ["326"], "contracts": ["39-41"], "copyrights": ["420-421"], "YouTube": ["9", "413", "416"], "CoreFirst": ["293"], "SOA transaction manager": ["293"], "cost advantages": ["17"], "Coyote Point Systems": ["97"], "Create PDF": ["343-344"], "Crescendo Networks": ["97"], "Crunch": ["344"], "Customer Relationship Management (CRM) software": ["26", "75", "358"], "Dailymotion": ["413"], "Dallas (SQL Azure Database)": ["207", "217"], "Dashboard Designer": ["142"], "AppBase": ["142"], "data abstraction services": ["280-281"], "Data Access Service (DAS)": ["274"], "data analysis": ["183"], "(AMIs)": ["187-188"], "cloud computing benefit": ["17"], "cloud computing characteristic": ["25"], "virtualization attribute": ["95"], "electronic business cards": ["83-84"], "vCards": ["84"], "(ebXML)": ["451"], "(XML)": ["272-273"], "Email client": ["344"], "Mail": ["358"], "MobileMe": ["435"], "push services": ["455-459"], "Windows Live core service": ["221"], "EMC Atmos": ["320"], "managed cloud storage": ["321"], "EMC\u2019s Digital Universe": ["313"], "emulation": ["102"], "hypervisors": ["103"], "Encoding.com": ["406"], "picture file conversions": ["406-407"], "connection security": ["59"], "data security": ["260"], "End User Agreement (EULA)": ["41-42"], "software": ["75"], "end users": ["81"], "OpenID authentication": ["81"], "enforcement": ["78"], "Engage": ["347"], "Enhanced Messaging Service (EMS)": ["460"], "smartphones": ["425"], "Enterprise Architect (EA)": ["288"], "unified modeling language": ["288"], "(IM)": ["386"], "Mashup Alliance": ["74"], "middleware orchestration": ["276"], "EtherApe": ["129"], "packet sniffer": ["128"], "Digital Universe": ["312-314"], "Digsby": ["387"], "collaboration software": ["392"], "Direct Attached Storage (DAS)": ["106"], "directory services": ["78"], "discovery": ["56"], "discussions": ["358", "394"], "disintermediation": ["156"], "disks": ["118"], "Distributed Common Object Model (DCOM)": ["57"], "Distributed Management Task Force (DMTF)": ["243"], "Distributed Resource Scheduler (DRS)": ["105"], "Distributed Task Format (DMTF)": ["107"], "document management": ["349-350"], "File Manager": ["349-350"], "document storage services": ["109"], "Simple Cloud API": ["308"], "DoJo Toolkit": ["147"], "WaveMaker interoperation": ["147"], "Domain Specific Language (DSL)": ["74"], "dotMOBI": ["448-449"], "mobile Web services": ["450-451"], "DoubleClick": ["162"], "targeted advertising": ["161"], "dpBestflow.org": ["327"], "Draw": ["344"], "drawing programs": ["344"], "Dropbox": ["317"], "file transfer utility": ["317"], "Drupal": ["140"], "Dsniff": ["129"], "Dynamics CRM": ["207"], "Earthlink": ["268"], "Jabber XCP": ["268"], "ease of use": ["341"], "productivity software characteristic": ["341"], "ease of utilization": ["17"], "ebXML": ["451"], "Eccentex AppBase 3.0": ["141"], "PaaS delivery platform": ["141-143"], "Eclipse": ["144"], "LongJump support": ["144"], "eCommerce": ["183"], "Edgecast Networks": ["199"], "edge-storage systems": ["183"], "e-Discovery": ["250"], "Agreements (SLAs)": ["42"], "File Sharing service": ["343"], "file storage services": ["109"], "file transfers": ["410"], "file-hosting services": ["316-317"], "file-sharing services": ["318-319"], "financial industry": ["388-389"], "instant messaging services": ["388-389"], "Find My iPhone": ["436"], "device tracking": ["436"], "Firefox 4 (WebM)": ["416"], "FlexiScale": ["11"], "Flickr": ["413"], "Force API": ["13"], "versus Salesforce.com": ["135-137"], "foreign languages": ["163-164"], "Google Translate": ["163"], "formulas": ["33-34"], "freebXM": ["451"], "ebXML standard": ["451"], "FreeDrive": ["316"], "file-hosting service": ["316"], "FriendFeed": ["399"], "friends": ["393"], "Friendster": ["392"], "Fring": ["411"], "Google Talk support": ["411"], "full system backups": ["325"], "cloud storage": ["311"], "full virtualization": ["102"], "functional specifications": ["286"], "SOA message element": ["286"], "game consoles": ["419"], "YouTube for TV": ["419"], "gateways": ["460-461"], "Gathera": ["399"], "Gemalto": ["184"], "Enzio Time Token": ["184"], "portal": ["8-9"], "Ghost": ["325"], "image backups": ["325"], "Glide Digital": ["344"], "online office system": ["355-360"], "Glide HD": ["345"], "Glide Mobile": ["347"], "Engage software": ["347"], "(REST)": ["57"], "identities": ["77"], "event contracts": ["273"], "event managers": ["351"], "Remember the Milk": ["351"], "event monitoring": ["78"], "Excel": ["352"], "Microsoft Office Web Apps": ["352"], "type": ["26"], "(XACML)": ["84"], "user authorization": ["84"], "Electronic Business": ["272-273"], "message passing format": ["273"], "VoIP": ["57"], "extension": ["25"], "cloud computing provider reason": ["25"], "external policy administration": ["78"], "eZ Publish": ["141"], "F5 Networks": ["96"], "Fabric": ["211", "213"], "FreeDrive storage service": ["317"], "Facebook games": ["181"], "Amazon Web services (AWS)": ["179"], "FACPS": ["232"], "network management": ["232"], "Family Safety": ["224-225"], "cloud computing": ["18"], "FedCloud": ["88"], "federated identity": ["78"], "Fifth C BlacMail Server": ["457"], "file servers": ["68"], "tools": ["166"], "application": ["211", "213"], "Google Commerce Search": ["159"], "enterprise market": ["159"], "cloud-based user application": ["152"], "mashups": ["137"], "Google Effect": ["152"], "Android application": ["432"], "search engine aggregation page": ["153-154"], "Google Gadgets": ["349"], "Google Docs functionality": ["349"], "Google Gears": ["166"], "offline access to online data": ["166"], "Webmail service": ["373-375"], "Google Goggles": ["432"], "Google Health": ["152"], "Google Listen": ["432"], "Google Mail": ["152"], "Google Mini": ["159"], "Google Postini Services": ["161"], "Google Profile": ["81"], "Chrome OS display": ["64"], "Google Search Appliance": ["159"], "Google Shopper": ["432"], "Google Site Search": ["159"], "Google Storage for Developers": ["320"], "Google Translator Toolkit": ["164"], "Google TV": ["415"], "Global Index P2P protocol": ["409"], "Gnip": ["399"], "GoGrid CloudCenter": ["11"], "GoGrid": ["10"], "maintenance": ["250-251"], "Gomez": ["116"], "App Engine for Business SLA": ["41"], "datacenter site factors": ["98"], "enterprise offerings": ["159-161"], "Google Fibre for Communities": ["130"], "indexed search technology": ["154-155"], "load balancing": ["95-100"], "MapReduce": ["294-295"], "PageRank": ["154"], "Privacy Center": ["156"], "productivity applications": ["156-159"], "Search Engine Results Page (SERP)": ["154"], "Sitemaps protocol": ["155"], "Software as a Service example": ["4"], "YouTube video-sharing service": ["417-421"], "Google Accounts API": ["177"], "Google Analytics Tracking Code (GATC)": ["163"], "Google Analytics": ["162"], "distributed datastore system": ["176-177"], "gallery page": ["177"], "language agnostic service": ["175"], "pricing schemes": ["175"], "resource limits": ["29-32"], "supported programming languages": ["175"], "Web hosting service": ["209"], "Google Apps for Business": ["160"], "Barksdale)": ["156"], "HIPAA": ["19"], "data privacy rules": ["19"], "Hitwise.com": ["362-363"], "hosting services": ["436-438"], "iPhone": ["436-438"], "Hotmail": ["362"], "Webmail service pioneer": ["362"], "Hotspot": ["59"], "HP Cloud Computing": ["233"], "HP LodeRunner": ["121"], "HP OpenView": ["232"], "HP Software and Solutions OpenView SOA Manager": ["292"], "HTML 5": ["416"], "supported media players": ["416"], "Note": ["354"], "productivity software": ["340"], "Wiki": ["359"], "HTML files": ["347-351"], "Google Docs": ["348-349"], "HTTP server push": ["456"], "HTTPerf": ["121"], "Hulu Plus": ["414"], "subscription TV service": ["414"], "TV over the Internet (TVIP)": ["414-415"], "Turk": ["183"], "Human Resource Information System": ["359"], "hybrid applications": ["304-307"], "hybrid cloud": ["7-9"], "operating system virtualization": ["103"], "paravirtualization": ["102"], "virtual machine types": ["100-103"], "VMware vSphere": ["103-107"], "Amazon Elastic Computer Cloud (EC2)": ["67"], "IBM AIX 6.1": ["103"], "IBM Cloud Computing": ["233"], "IBM Lotus Sametime": ["386"], "instant messaging (IM)": ["384"], "IBM Rational Performance Tester": ["121"], "IBM Smart Business Storage Cloud": ["320"], "Manager for SOA": ["292"], "API listings": ["168-173"], "application diversity": ["151"], "Code Page": ["165"], "developer programs": ["151"], "development services": ["165-173"], "development tools": ["166"], "GoogleApps": ["13"], "SaaS model": ["13"], "GoogleTalk": ["59-60"], "Gbridge VNC software": ["59-60"], "governance": ["280-281"], "Gramm-Leach-Bliley Act (GLBA)": ["256"], "graphics modules": ["340"], "datacenters": ["28"], "grid computing": ["19"], "group chats": ["410"], "groups": ["393"], "GSMA OneAPI": ["449"], "mobile API standards": ["449"], "H.264/MPEG-4 Part 10 format": ["416-417"], "streaming video": ["416-417"], "H.323": ["409"], "Voice over IP (VoIP) standard": ["409"], "headers": ["286"], "(HIPAA)": ["256"], "HelpdeskLive": ["53"], "Hibernate": ["147"], "WaveMaker support": ["147"], "hierarchical topology": ["289-291"], "business type": ["26"], "EC2": ["190-196"], "BlackBerry devices": ["438"], "chat enhancements": ["385"], "clients": ["384-386"], "Enterprise Instant Messaging (EIM)": ["386"], "IMPS": ["387"], "Session Initiation Protocol (SIP)": ["387"], "SIMPLE protocol": ["57"], "Windows Live Messenger": ["384", "385-386"], "XMPP": ["387"], "instrumentation": ["134"], "integrated development environment (IDE)": ["138"], "integration": ["289"], "intelligent switches": ["95"], "load balancing support": ["95"], "Inter Applications Communications (IAC)": ["341-342"], "interaction": ["399-400"], "interactivity": ["341"], "Intercloud Testbed": ["294"], "statistics": ["312"], "study": ["426"], "Internet Archive": ["413"], "Internet": ["4"], "Internet delivery": ["95"], "protocol": ["272"], "IBM Tivoli Service Automation Manager": ["233"], "iChat": ["436"], "identity characteristics": ["76-78"], "open standards": ["80"], "service classes": ["78-79"], "user authentication": ["81-84"], "standards": ["19"], "identity governance": ["78"], "protocol standards": ["264-266"], "exchanges": ["84-87"], "iDisk": ["436"], "iDrive": ["316"], "iGoogle": ["380-382"], "syndicated content": ["380-382"], "incremental backups": ["326"], "indexed search": ["154-155"], "Information Card": ["82-83"], "Amazon Web Services (AWS)": ["180"], "cloud computing ecosystem": ["66"], "NIST model": ["6"], "pods": ["69-70"], "Rackspace Cloud": ["67", "181", "321"], "silos": ["69-70"], "workloads": ["67-69"], "real to virtual asset conversion": ["35-36"], "right-sizing demand load": ["36-37"], "Kazaa": ["409"], "Skype development history": ["409"], "key management": ["260"], "Measurement Index (SMI)": ["246", "248"], "Keynote": ["116"], "Kismet": ["128"], "Krogh": ["327"], "Peter": ["327"], "KVM": ["101"], "Type 2 Virtual Machine Monitor": ["101"], "Kyte": ["413"], "languages": ["163-164"], "large corporations": ["18-19"], "Last.fm": ["404"], "music services": ["404"], "LDAP directories": ["147"], "Lemonade Profile": ["459"], "LIAS": ["293"], "Enterprise SOA Testing platform": ["293"], "(IGF)": ["80-81"], "licensing models": ["41-42"], "lifecycles": ["237"], "LifeForms": ["147"], "WaveMaker data forms": ["147"], "lifestream management": ["400"], "Limelight Networks": ["199"], "Linode": ["11"], "Linux": ["115"], "MySQL": ["115"], "PHP (LAMP) solution stack": ["115"], "LAMP solution stack component": ["115"], "Live Mesh Mobile": ["227"], "live streaming": ["404"], "progressive streaming": ["404"], "LiveLayout": ["147"], "Visual Ajax Studio": ["147"], "Liveops.com": ["15-16"], "call center operations company": ["15-16"], "Application Delivery Controller (ADC)": ["96-97"], "supported network resources": ["95"], "capacity planning element": ["115"], "location awareness": ["454-455]"], "logging": ["261-263"], "security": ["293-294"], "logical context": ["452"], "logical design": ["289"], "protocols": ["405"], "package": ["293"], "intranets": ["4"], "Intuit": ["12"], "QuickBooks": ["12"], "iOS operating system": ["433-434"], "Apple iPhones": ["433-434"], "standard": ["409"], "iPhones": ["390"], "Twitter app": ["390"], "Iron Mountain": ["320"], "systems": ["262"], "IT management": ["17"], "(XMPP)": ["57"], "iTKO": ["293"], "LISA": ["293"], "streaming": ["416-417"], "iWeb Publish": ["436"], "XCP)": ["268"], "Java frameworks": ["147"], "Java": ["175"], "Google App Engine (GAE) support": ["175"], "Java Platform Micro Edition": ["430"], "Java pushlet": ["456"], "JavaScript": ["163"], "Jcinacio": ["53"], "Jericho Forum": ["6"], "Jingle protocol": ["411"], "Google Talk": ["411"], "JMeter": ["121"], "load generation tool": ["121"], "Joint Innovation Lab": ["449"], "Joint Video Team (JVT)": ["416-417"], "Joomla!": ["141"], "Jumpbox": ["54"], "memory (RAM)": ["118"], "message logging": ["410"], "Message Passing Interface (MPI)": ["103"], "process VM": ["103"], "Service": ["182"], "message queues": ["181"], "message transactions": ["375-376"], "(WSDL)": ["283-286"], "messaging format": ["45"], "XML protocol": ["45"], "Metacafe": ["413"], "metered usage": ["95"], "Micro Focus (Borland) SilkPerformer": ["121"], "micro-blogs": ["388-391"], "services": ["227-228"], "Azure Platform": ["5", "13"], "media center PC interface": ["414"], "WebTV (MSN TV)": ["414"], "Windows Product Activation": ["77-78"], "interoperation": ["147"], "Microsoft adcenter": ["161"], "Microsoft App-V": ["110"], "application delivery platform": ["110"], "Azure AppFrabic": ["207"], "Compute": ["211", "213"], "development environment": ["206"], ".NET Framework": ["206"], "SharePoint Services": ["207"], "SQL Azure Database": ["207"], "Storage": ["207"], "virtualized infrastructure": ["207"], "Web app types": ["206"], "Windows Live": ["227"], "Logical Unit Number (LUN)": ["322-323"], "storage partitions": ["322-323"], "Loki": ["455"], "Skyhook network support": ["455"], "benefit": ["17"], "characteristic": ["24"], "obstacles": ["29-32"], "lower costs": ["17"], "LynxSecure": ["100"], "Type 1 Virtual Machine Monitor": ["100"], "Mail Delivery Agent (MDA)": ["456"], "Mail User Agent (MUA)": ["456"], "network management element": ["232"], "MalStone": ["294"], "OCC data generator": ["294"], "Management Suite": ["241"], "distributed large data sets": ["294-295"], "Ajax (Asynchronous JavaScript and XML)": ["27", "74"], "components": ["274"], "Google Earth": ["137"], "WaveMaker": ["146"], "measured service": ["17"], "Media Access Control (MAC) addresses": ["77"], "television": ["414"], "media files": ["344"], "Media Player": ["344"], "IP (VoIP) standard": ["409"], "Media Player Classic": ["416"], "HTML 5 support": ["416"], "media players": ["416"], "Meebo": ["387"], "synchronization": ["465"], "Synchronization Markup Language (SyncML)": ["464-465"], "Wireless Application Protocol (WAP)": ["461-464"], "mobile XMPP clients": ["411"], "MobileMe Gallery": ["436"], "photo/video-sharing": ["436"], "mobility applications": ["26"], "cloud computing business type": ["26"], "mobility patterns": ["94-95"], "monitoring services": ["280-281"], "Moovida Core": ["416"], "Movie Maker": ["224"], "MP3 files": ["407-408"], "audio streaming": ["408"], "specification": ["56"], "method": ["77"], "Multimedia Messaging Service (MMS)": ["460"], "multi-tenancy": ["5"], "resource sharing": ["5"], "My Tracks": ["432"], "Mybloglog": ["399"], "MyOpenID": ["81"], "myZuzu": ["399"], "NASA": ["20"], "Nebula Cloud Platform": ["20"], "cloud computing definitions": ["5-6"], "National Public Radio (NPR)": ["408"], "Microsoft Exchange ActiveSync": ["457"], "Microsoft Hyper V": ["101"], "Microsoft IIS": ["140"], "Microsoft Internet Explorer": ["416"], "Microsoft Network Monitor": ["128"], "network capacity": ["129-130"], "messaging (IM)": ["386"], "Microsoft Windows Azure": ["143"], "Microsoft\u2019s Silverlight": ["416"], "(UDDI)": ["451"], "Miranda IM": ["387"], "mirroring backups": ["326"], "cloud storage backups": ["327"], "broadband subscriptions": ["427"], "cell phone statistics": ["426"], "Glide Mobile\u2019s Engage": ["347"], "microelectromechanical systems (MEMS)": ["453-454"], "operating systems": ["425"], "YouTube Mobile": ["419"], "Mobile Top Level Domain (mTLD)": ["446-447"], "content-aware services": ["451-453"], "discovery protocols": ["450-451"], "optimization factors": ["446"], "physical context": ["452"], "(KMIP)": ["260"], "OAuth": ["265"], "token service provider": ["265"], "Obicore": ["245"], "(SOAP)": ["45"], "cloud computing challenges": ["29-31"], "on-demand self service": ["17"], "on-demand streaming": ["404"], "stored content": ["404"], "OneNote": ["352"], "online backups": ["182"], "online forums": ["358"], "Discussions": ["358"], "pros/cons": ["342-343"], "Zoho Office Suite": ["355-360"], "Open Cloud Consortium (OCC)": ["294-295"], "Open Cloud Manifesto": ["440"], "Symbian platforms": ["440"], "Open Cloud Testbed": ["294"], "open file backups": ["326"], "Open Grid Foundation (OGF)": ["311"], "Open Group": ["6"], "Open Handset Alliance": ["431-432"], "Android support": ["431-432"], "Open Mashup Alliance": ["74"], "enterprise mashups": ["74"], "Protocol (WA)": ["461-462"], "open source software": ["73-74"], "Software as a Service (SaaS)": ["311"], "National Weather Service": ["268"], "netbooks": ["60-61"], "Jolicloud OS": ["60-61"], "Netflix": ["414"], "subscription movie service": ["414"], "Microsoft Cloud Services": ["233"], "NetScaler 9.0": ["293"], "Network Attached Storage (NAS)": ["106"], "network bandwidth": ["404-405"], "streaming media": ["405"], "assessment elements": ["128"], "Google Fiber for Communities": ["130"], "network monitors": ["128-129"], "packet sniffers": ["129-130"], "WAN capacity factors": ["129"], "network connectivity": ["118"], "Network Insights": ["399"], "network interfaces": ["95"], "component": ["68"], "monitoring": ["234-236"], "network capacity measurement": ["128-129"], "network protocols": ["282-283"], "SOA communications": ["282-283"], "network topology": ["289-291"], "Networking Bible (Barrie Sosinsky)": ["55", "405"], "Networks": ["96"], "news aggregators": ["378-382"], "Newsgator Online": ["377"], "newsreaders": ["377-378"], "syndication services": ["377-378"], "Nico Nico Douga": ["413"], "Nimbuzz": ["411"], "Nimsoft United Monitoring": ["245"], "Nirvanix": ["321"], "Nortel Networks": ["97"], "Notebook ZoHo Office Suite": ["357"], "Ntop": ["129"], "NutshellMail": ["399"], "Parallel Virtual Machine": ["103"], "Monitor": ["100"], "(PCI-DSS)": ["256"], "payment services": ["184"], "performance optimization": ["232"], "performance": ["134"], "personal information managers": ["340"], "personal profiles": ["393"], "Photo Editor": ["345"], "Photo Gallery": ["224"], "photos": ["221"], "PHP": ["115"], "pattern": ["94"], "Picasa": ["152"], "file conversions": ["406-407"], "Pidgin": ["387"], "Pingdom": ["116"], "Places Directory": ["432"], "over IP (VoIP)": ["409"], "collaboration": ["134"], "desirable attributes": ["134-135"], "identity protocol standard": ["264-265"], "user centric authentication": ["80"], "OpenID Foundation": ["81"], "Open ID trusted providers": ["81"], "OpenSocial": ["399"], "social networking interoperability": ["399"], "open-source software": ["19"], "OpenSTA": ["121"], "OpenStack": ["20"], "Opera 10.6+": ["416"], "Amazon Machine Images (AMIs) supported types": ["188-189"], "Chrome": ["61-64"], "Jolicloud": ["60"], "operation monitoring": ["232"], "OpTier": ["293"], "optimization": ["25"], "Oracle Beehive": ["386"], "Oracle BPEL Process Manager": ["282"], "SOA management tool": ["282"], "Oracle on Demand": ["13"], "Oracle VM": ["100"], "Orange": ["81"], "service process flow": ["58"], "order filling": ["184"], "Information... (OASIS)": ["287"], "OrSiSo": ["399"], "ownership": ["6-7"], "Cloud Cube Model dimension": ["7"], "Ozer": ["417"], "Jan": ["417"], "WebM versus H.264 analysis": ["417"], "page views": ["115"], "Google algorithm": ["154"], "Presentation package": ["343"], "Presenter": ["344"], "Show": ["354", "357"], "Google policies": ["156"], "(ESB)": ["280-281"], "computations": ["37-39"], "profile management": ["78"], "profits": ["25"], "Progress Software": ["294"], "Project Hosting": ["166"], "project management tool": ["166"], "project management": ["357"], "project planners": ["340"], "Projects": ["357"], "proprietary applications": ["58-59"], "client connection method": ["58"], "Provisioning Service Point (PSP)": ["86"], "LongJump": ["143"], "versus SaaS": ["135-137"], "Squarespace": ["145"], "storage": ["211", "213"], "testing": ["134"], "transaction management": ["45"], "Wolf Frameworks": ["147-149"], "Plaxo": ["399"], "Plocky": ["399"], "podcasts": ["377"], "RSS feeds": ["377"], "policies": ["78"], "markup languages": ["84"], "Policy Decision Point (PDP)": ["84"], "Policy Enforcement Point (PEP)": ["84"], "Policy Information Point (PIP)": ["84"], "policy management": ["232"], "Portable Document Format (PDF) files": ["343-344"], "Posterous": ["146"], "Web site builder": ["146"], "PowerBuilder": ["146"], "application development environment": ["146-147"], "PowerPoint": ["352-353"], "security concepts": ["267-268"], "Presentation Builder": ["142"], "recovery": ["250"], "registration": ["78"], "regulatory compliance": ["250"], "communication (IPC)": ["55"], "Replify": ["108"], "Report Builder": ["142"], "operating system": ["438-440"], "reservation systems": ["304-307"], "resource configuration": ["232"], "Resource Data Framework": ["452"], "resource pooling": ["17"], "resource provisioning": ["232"], "network management t": ["232"], "resource virtualization": ["19"], "response times": ["39"], "responsibilities": ["40"], "Return on Investment (ROI)": ["38-39"], "Reverse Delta backups": ["326"], "Rhapsody": ["404"], "Rightscale": ["240"], "RimHosting": ["308"], "RIM\u2019s BlackBerry Enterprise Server": ["457"], "risk monitoring": ["78"], "roles": ["78"], "performance measurement": ["118-119"], "RSS feed aggregator": ["349"], "Reader": ["349"], "RSS services": ["456"], "RTS Hypervisio": ["100"], "RuTube": ["413"], "Provisioning Service Targets (PST)": ["86"], "provisioning": ["78"], "proxy services": ["256-259"], "pseudo-streaming": ["405"], "progressive downloads": ["405"], "public cloud": ["7-9"], "Public Data Sets": ["198"], "Public Key Infrastructure (PKI)": ["294"], "Push-IMAP": ["456"], "Python": ["175"], "QEMU": ["54"], "Wireless": ["430"], "Quality of Service (QoS)": ["17"], "QuickTime": ["407"], "audio/video streaming": ["407"], "Rackserve PCI": ["88"], "AWS IP assignment model": ["67"], "Rackspace Cloud Servers": ["308"], "Radware": ["97"], "rapid elasticity": ["17"], "Real Networks": ["407"], "RealPlayer": ["407"], "National Public Radio": ["408"], "document feeds": ["376-377"], "Real-time Streaming Protocol (RTSP)": ["405"], "Real-time Transfer Protocol (RTP)": ["405"], "Real-time Transport Control Protocol (RTCP)": ["405"], "(VoIP) standard": ["409"], "presence": ["267-268"], "Sarbanes-Oxley Act (SOX)": ["19", "256"], "token services": ["265"], "troublesome areas": ["250"], "Windows Azure identity standards": ["266"], "information exchanges": ["84-87"], "security boundary": ["7"], "security enforcement": ["232"], "Security Roles Management": ["142"], "Security Token Service (STS)": ["294"], "sequencing": ["405"], "streaming files": ["404"], "service brokers": ["18"], "cloud component controls": ["58"], "service catalogs": ["281-282"], "Identity as a Service (IDaaS)": ["78-79"], "Service Data Object (SDO)": ["274"], "SOA data exchanges": ["274"], "Amazon": ["41"], "service providers": ["39-41"], "CA Cloud Insight": ["245", "246-248"], "cloud types": ["5-6", "9-13"], "NIST definitions": ["5-6"], "versus Force.com": ["135-137"], "mobile access": ["429"], "scaling": ["131"], "horizontal versus vertical scaling": ["131"], "schedulers": ["340"], "secure protocols": ["59"], "analysis elements": ["250"], "auditing": ["261-263"], "boundaries": ["251-254"], "cloud computing disadvantages": ["18"], "data storage locations": ["259-260"], "encryption": ["260"], "\u201cgolden\u201d system image references": ["250-251"], "identity management": ["263-266"], "identity protocols": ["264-266"], "ISO/IEC 2700/27002 standard": ["262"], "mapping": ["255-256"], "definitions": ["6"], "Service Provisioning Markup Language (SPML)": ["86"], "service quality": ["17"], "service types": ["286"], "service-based": ["95"], "Service-Now.com": ["241"], "ITSM SaaS service": ["241"], "Service-Oriented Modeling Framework (SOMF)": ["288-289"], "Architecture (Michael Bell)": ["275"], "Seven": ["457"], "shared services": ["95"], "document and collaboration service": ["207"], "Windows Azure Platform support": ["205"], "Sheet": ["356"], "short code": ["461"], "SMS phone numbers": ["461"], "text messaging": ["388-391"], "SHOUTcast": ["408"], "Drupal CMS": ["140"], "Siege": ["121"], "porting application": ["109"], "object model protocol": ["45"], "service orientation": ["19"], "architectural elements": ["210-212"], "Business Process Execution Language (BPEL)": ["286-287"], "business process modeling": ["287-292"], "Business Process Modeling Notation (BPMN)": ["288"], "choreography": ["275", "277"], "cloud computing relationships": ["295-296"], "distributed application platform": ["272"], "event-driven (SOA 2.0)": ["277-278"], "management tools": ["292-293"], "message passing formats": ["273"], "middleware implementation": ["272"], "orchestration methods": ["274-275"], "protocol stacks": ["273-274"], "request management": ["271-272"], "Service Component Architecture (SCA)": ["274"], "Systems Modeling Language (SysML)": ["288"], "unidirectional data exchange": ["268"], "Unified Modeling Language (UML)": ["288"], "Web Service Business Process Execution Language": ["286-287"], "Web Service Description Language (WSDL)": ["283-286"], "XML Metadata Interchange (XMI)": ["288"], "mashup components": ["74"], "versus PaaS": ["135-137"], "Sosinsky": ["55", "405"], "Barrie (Networking Bible)": ["55", "405"], "sourcing": ["7"], "Sparx Systems": ["288"], "SPML provisioning language": ["80"], "Spot Instance": ["187-188"], "Tables": ["343"], "Spring Framework": ["147"], "relational database service": ["217"], "cloud-enabled database": ["207"], "star topology": ["289-291"], "stateless cloud": ["110"], "virtual application appliance": ["110"], "stateless system": ["18"], "statistical tools": ["162-163"], "non-relational storage facility": ["207"], "Simple Queue Services": ["109"], "single sign-on services": ["78"], "(SIMPLE)": ["387"], "SiteUpTime": ["116"], "SkyDrive": ["351-352"], "Skyhook Wireless": ["455"], "location service": ["454-455"], "SkypeIn service": ["411"], "small corporations": ["17-18"], "Research in Motion Blackberry": ["438-440"], "Symbian": ["440-441"], "Windows Mobile": ["441-442"], "snapshots": ["326"], "cloud storage backup": ["326"], "(Michael Bell)": ["275"], "Facebook": ["392-393"], "MySpace": ["81"], "privacy issues": ["398"], "site listing": ["394-398"], "Twitter": ["392"], "disadvantages": ["18"], "Yahoo! Search Marketing": ["161"], "TCPdump": ["128"], "technical support": ["184"], "Teeter": ["156"], "Ryan (Google Apps For Dummies)": ["156"], "teleconferencing": ["456"], "YouTube XL interface": ["419"], "Terremark": ["11"], "test bed labs": ["26"], "text-notification": ["459-461"], "Thomson Reuters Messaging": ["388"], "financial industry IM": ["388-389"], "ThoughtPolice": ["54"], "Thurrott": ["441"], "Paul (Windows Phone 7 Secrets)": ["441"], "Tidal Software": ["293"], "Intersperse": ["293"], "Time Machine": ["326"], "Reverse Delta backup": ["326"], "Calendar": ["350-351"], "DaaS": ["320"], "Storage Networking Industry Association": ["333-335"], "CDMI": ["333-335"], "storage resources": ["95"], "storage systems": ["211", "213"], "Storage VMotion": ["105"], "datastore file migration service": ["105"], "storage virtualization": ["321-322"], "audio": ["407-408"], "bandwidth requirements": ["404-405"], "unicast": ["404"], "unicast protocols": ["404"], "StreamingMedia.com": ["417"], "Sun Solaris": ["103"], "Sun xVM Server": ["100"], "Web services": ["451"], "Really Simple Syndication (RSS)": ["376-377"], "system snapshots": ["107"], "system implementation": ["289"], "U.S. Marine Corps": ["268"], "ubiquity": ["234"], "unidirectional nature": ["18"], "upgrades": ["18"], "Upstart": ["62"], "Chromium Linux kernel": ["62"], "uptime": ["39"], "user agents": ["57"], "User Datagram Protocol (UDP)": ["405"], "user interface": ["74"], "mashup component": ["74"], "user-centric": ["341"], "user-facing": ["341"], "UStream.tv": ["413"], "utility": ["25"], "utilization": ["17"], "identity data storage": ["83-84"], "OpenID": ["264"], "vCenter Server": ["103"], "vComputer": ["103"], "Veoh": ["413"], "Verisign": ["81"], "video conferencing": ["410"], "TiVo": ["419"], "To-Do lists": ["351"], "Todou": ["413"], "tokens": ["265"], "Tomcat": ["147"], "Total Cost of Ownership (TCO)": ["37-39"], "product or services": ["37-39"], "transaction attributes": ["286"], "Web Services Description Language (WSDL)": ["45"], "atomic transaction": ["298"], "(TCP)": ["405"], "translation applications": ["163-164"], "media": ["405"], "Trillian": ["387"], "trust services": ["77"], "multifactor authentication": ["77"], "Trusted Platform Module": ["62"], "trusted providers": ["81"], "URL formats": ["81"], "Tumblr": ["146"], "Hulu.com": ["414-415"], "U.S. Copyright Act of 1976": ["420-421"], "YouTube videos": ["420-421"], "U.S. Joint Forces Command (USJFCOM)": ["268"], "Google Voice": ["411-412"], "voice telephony": ["410"], "vStorage": ["103"], "WAN connectivity": ["18"], "warranties": ["40"], "Web 2.0": ["26"], "Web servers": ["68"], "Simple Object Access Protocol (SOAP)": ["55"], "WS-star specifications": ["56"], "SOA message passing": ["283-286"], "Web Services Security (WSS)": ["273"], "Web site managers": ["340"], "container formats": ["416-417"], "file formats": ["416-417"], "services listing": ["222-223"], "Amazon Machine Images": ["52"], "VirtualLogix VLX": ["100"], "VLC": ["416"], "Vmachines": ["54"], "VMotion": ["105"], "virtual machine migration service": ["105"], "VMware ESX": ["100"], "VMWare Fusion": ["101"], "VMware ThinApp": ["110"], "VMWare vCloud": ["308"], "framework": ["103-107"], "Machine Monitor": ["101"], "VMware\u2019s Virtual Appliances": ["53"], "management": ["105"], "vNetwork": ["103"], "Voice Actions for Android": ["432-433"], "Atom Publishing Protocol": ["377"], "backbone maps": ["29"], "BackEndBattles": ["162"], "Builtwith": ["162"], "CA\u2019s Cloud Connected Management Suite": ["244"], "CDNetworks": ["97"], "Chromium": ["62"], "Web site traffic": ["183"], "Alexa": ["97"], "Amazon Elastic Block Store": ["182"], "Amazon Elastic Compute Cloud (EC2)": ["181-182"], "Amazon Relational Database Service": ["182"], "Amazon Web Services\u2019 Auto Scaling": ["37"], "(EC2) SLA": ["42"], "AMI library": ["52"], "Apple TV": ["415"], "Gbridge": ["59"], "Apps.gov portal": ["8-9"], "Glide Digital OS4": ["346"], "Google AJAX crawling": ["155"], "Google App Engine Gallery": ["177"], "Google Apps Marketplace": ["166"], "Google Finance": ["154"], "Google Gmail": ["366-369"], "Google Privacy Center": ["156"], "Google Reader": ["377", "379"], "Google Web Toolkit": ["166"], "Google\u2019s App Engine for Business SLA": ["41"], "Google\u2019s Code Home page for developers": ["165"], "Dan Ariely\u2019s article": ["31"], "David Chappel\u2019s SCA white paper": ["274"], "Dojo Toolkit": ["147"], "dotMOBI domain": ["448-449"], "Eucalyptus": ["21"], "Expand Networks": ["97", "108"], "Experian\u2019s Hitwise.com": ["362"], "Liberty Alliance": ["80"], "Mail2Web": ["369-370"], "ManageIQ": ["241"], "Matjaz Juric\u2019s BPEL primer": ["275"], "Message Passing Interface": ["103"], "Microsoft": ["81", "207"], "Microsoft Office Communications Server": ["386"], "Microsoft Service Level Agreements (SLAs)": ["40"], "Microsoft\u2019s economics page": ["38"], "Microsoft\u2019s Office Live": ["353"], "More Google Products": ["152"], "(NIST)": ["5"], "OASIS": ["287"], "Guttenburg.org": ["314"], "Higgins Open Source Identity Framework": ["83"], "Manager": ["292"], "Hulu": ["413"], "IBM\u2019s SOA Foundation White Paper": ["273"], "Computing": ["21"], "(ITIL)": ["282"], "International Data Corporation (IDC)": ["312"], "International Telecommunications Union": ["426"], "Intuit QuickBooks": ["12"], "Jitendra Pal Thethi\u2019s white paper": ["26"], "Cloudonomics": ["31"], "Joe Wienman\u2019s 10 Laws of Cloudonomics": ["27"], "Juniper Networks": ["97"], "Round Robin Database tool (RRDTool)": ["118"], "RSS Advisory Board": ["376"], "Salesforce.com": ["429"], "Sectools.org": ["128"], "Security Assertion Markup Language (SAML)": ["264"], "Azure Apps": ["257"], "Simple API for Cloud Application Services": ["109"], "SMS gateways": ["461"], "SOMF diagram": ["292"], "SOMF white paper": ["292"], "Storage Networking Industry Association (SNIA)": ["320", "333"], "Symbian Foundation": ["440"], "U.S. Federal Cloud Computing Initiative": ["8-9"], "Laboratory": ["25"], "OASIS standards": ["293"], "Object Management Group": ["288"], "Open Grid Forum": ["335"], "Open Mobile Alliance (OMA)": ["462"], "Open Terminal Platform": ["449"], "OpenID 2009 Year in Review": ["264"], "programming language generations article": ["139"], "Proposed Standard RFC 4287": ["377"], "Rackspace.com": ["20"], "YuMe": ["413"], "Zend": ["109"], "WebM format": ["417"], "account statistics": ["362"], "deleting inactive accounts": ["362"], "development": ["362"], "features listing": ["364-366"], "pricing structure": ["217-219"], "Windows Live Hotmail": ["370-373"], "Yahoo! Mail": ["457"], "widgets": ["394"], "Android smartphones": ["432"], "best selling phones": ["429-430"], "cell phone usage": ["426"], "iOS devices": ["434"], "Winamp": ["416"], "Wind River Simics": ["101"], "Windows Azure": ["308"], "VirtualBox": ["54"], "W3C Mobile Web Initiative": ["446"], "Web Ontology Language (OWL)": ["452"], "WebM": ["417"], "Wholesale Applications Community (WAC)": ["449"], "Wikipedia": ["426"], "Wikipedia bandwidth calculations": ["404"], "machines": ["102"], "Wikipedia Twitter clients": ["390"], "Wikipedia\u2019s Total Cost of Ownership": ["38"], "Windows Live Instant Messenger": ["384"], "Windows Live Messenger Connect": ["219-221"], "Windows Mobile Device Center": ["465"], "Windows Phone 7": ["442"], "Windows Server AppFabric": ["215"], "Wireshark": ["128"], "WordPress": ["81", "146"], "WorkXpress": ["139"], "World Wide Web Consortium": ["55"], "WSDL primer": ["284"], "XACML": ["84"], "XBMC": ["416"], "Xen": ["53"], "XMPP Over BOSH": ["456"], "Yahoo Video": ["413"], "Yahoo!": ["81"], "Yahoo! Instant Messenger": ["384"], "Windows Live Profile Mobile": ["228"], "Windows Live Services": ["205", "207", "219-221"], "Windows Azure platform": ["205", "207", "219-221"], "Windows Live SkyDrive Mobile": ["228"], "Windows Live Spaces Mobile": ["228"], "Windows Media Player": ["407"], "Windows Phone 7 Secrets (Paul Thurrott)": ["441"], "data items": ["77-78"], "local server deployment": ["215"], "Windows Virtual PC": ["101"], "protocol stack": ["463"], "Wireless Data Network": ["463"], "WAP 1.2 protocol stack": ["463"], "stack": ["462"], "portable SaaS solutions": ["147-149"], "Write": ["344", "354"], "Writer": ["356"], "Word": ["352"], "workspaces": ["344"], "5GL PaaS": ["139"], "fabric": ["211", "213"], "identity standards": ["266"], "software plus services": ["210"], "supported services": ["205"], "virtual machines": ["211", "213-214"], "Windows Live services": ["219-221"], "access methods": ["221"], "discontinued/rebranded services": ["224"], "e-mail": ["221"], "online storage": ["221"], "Windows Live Calendar Mobile": ["227"], "Windows Live Contacts Mobile": ["227"], "Windows Live Groups Mobile": ["227"], "Windows Live Home Mobile": ["227"], "Windows Live Home": ["226-227"], "Windows Live suite portal": ["226-227"], "developer access": ["219-221"], "Windows Live Messenger Mobile": ["227"], "Windows Live Office Mobile": ["228"], "Yahoo! Video": ["413"], "Adobe Flash requirement": ["418-419"], "compatible browsers": ["416"], "copyright issues": ["420-421"], "site rankings": ["418"], "supported file formats": ["420"], "TV interface": ["419"], "U.S. Government channel": ["9"], "video-sharing service": ["417"], "White House channel": ["9"], "Zend_Cloud framework": ["109"], "WS-SecureConversion": ["294"], "WS-Security (WSS)": ["293"], "WS-SecurityPolicy": ["294"], "WS-Trust": ["294"], "XACML policy language": ["80"], "XDAS audit system": ["80"], "XML-RPC": ["55"], "interprocess communication (IPC)": ["55"], "XMPP/Jabber protocol": ["411"]}

# %%
#print(sorted(concepts.keys()))
concepts_list = list(sorted(concepts.keys()))
#for k in sorted(concepts.keys()):
#  print(k)

# %%
import numpy as np
from torchtext import data
from torchtext.vocab import GloVe
from cove import cove

TEXT = data.Field(lower=True, include_lengths=True, batch_first=True)

# train loader
train_dataset = data.TabularDataset(
        path="concepts_sorted.csv", format='csv',
        skip_header = False,
        fields={'concepts':[('concepts',TEXT)]
                })

TEXT.build_vocab(train_dataset, vectors=GloVe(name='840B', dim=300, cache='/content/drive/My Drive/nn4nlpdata'))
outputs_cove_with_glove = cove.MTLSTM(n_vocab=len(TEXT.vocab), vectors=TEXT.vocab.vectors, 
                                  residual_embeddings=True, model_cache='.embeddings')

train_iter = data.Iterator(
    (train_dataset),
    batch_size=1, shuffle=False)

# %%
embeddings = {}
for batch_num, batch in enumerate(train_iter):
    glove_then_last_layer_cove = outputs_cove_with_glove(*batch.concepts)

    v1 = glove_then_last_layer_cove[0].sum(axis=0)
    embeddings[concepts_list[batch_num]] = v1.detach().numpy()

# %%
from numpy import linalg as LA

semantic_relatedness = {}
for key1 in embeddings:
  for key2 in embeddings:
    if key1.lower() != key2.lower():
      v1 = embeddings[key1]
      v2 = embeddings[key2]
      if not np.array_equal(v1, v2):
        semantic_relatedness[key1 + " | " + key2] = (1 + (v1.dot(v2)) / (LA.norm(v1) * LA.norm(v2) ) )
        semantic_relatedness[key1 + " | " + key2] /= 2

# %%
import operator
sorted_d = dict(sorted(semantic_relatedness.items(), key=operator.itemgetter(1),reverse=True))

# %%
sorted_d
# Out:
# {'streaming video | video streaming': 0.9994811415672302,
#  'video streaming | streaming video': 0.9994811415672302,
#  'BlackBerry Enterprise Server (BES) | RIM’s BlackBerry Enterprise Server': 0.9993519186973572,
#  'RIM’s BlackBerry Enterprise Server | BlackBerry Enterprise Server (BES)': 0.9993519186973572,
#  'CA’s Cloud Connected Management Suite | Cloud Connected Management Suite': 0.9992799162864685,
#  'Cloud Connected Management Suite | CA’s Cloud Connected Management Suite': 0.9992799162864685,
#  'Total Cost of Ownership (TCO) | Wikipedia’s Total Cost of Ownership': 0.999060869216919,
#  'Wikipedia’s Total Cost of Ownership | Total Cost of Ownership (TCO)': 0.999060869216919,
#  'App Engine for Business SLA | Google’s App Engine for Business SLA': 0.9990454614162445,
#  'Google’s App Engine for Business SLA | App Engine for Business SLA': 0.9990454614162445,
#  'Amazon Elastic Block Store | Amazon Elastic Block Store (EBS)': 0.9989946782588959,
# ...

# %%
import numpy as np
from torchtext import data
from torchtext.vocab import GloVe
from cove import cove
import csv

def return_scores(concept1, concept2, type="GC"):

  concepts = ["concepts", concept1, concept2]
  with open('temp.csv','w') as result_file:
    wr = csv.writer(result_file)
    for concept in concepts:
      wr.writerow([concept,])

  TEXT = data.Field(lower=True, include_lengths=True, batch_first=True)

  train_dataset = data.TabularDataset(
          path="temp.csv", format='csv',
          skip_header = False,
          fields={'concepts':[('concepts',TEXT)]
                  })

  TEXT.build_vocab(train_dataset, vectors=GloVe(name='840B', dim=300, cache='/content/drive/My Drive/nn4nlpdata'))
  outputs_cove_with_glove = cove.MTLSTM(n_vocab=len(TEXT.vocab), vectors=TEXT.vocab.vectors, 
                                    residual_embeddings=True, model_cache='.embeddings')

  train_iter = data.Iterator(
      (train_dataset),
      batch_size=1, shuffle=False)

  embeddings = {}
  for batch_num, batch in enumerate(train_iter):
    glove_then_last_layer_cove = outputs_cove_with_glove(*batch.concepts)

    v1 = glove_then_last_layer_cove[0].sum(axis=0)
    embeddings[concepts[batch_num+1]] = v1.detach().numpy()

  v1 = embeddings[concept1]
  v2 = embeddings[concept2]
  semantic_relatedness = (1 + (v1.dot(v2)) / (LA.norm(v1) * LA.norm(v2) ) )
  semantic_relatedness /= 2

  return semantic_relatedness

# %%
return_scores("Java", "Java pushlet", "GC")
# Out:
# 0.9970679581165314
